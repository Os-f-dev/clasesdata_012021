# %%
import dask
import dask.dataframe as dd

# %%
import pandas as pd

# %%
df_pandas = pd.read_csv('flights.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b74b302dd76e> in <module>
# ----> 1 df_pandas = pd.read_csv('flights.csv',assume_missing=True)
#
# TypeError: parser_f() got an unexpected keyword argument 'assume_missing'

# %%
df_pandas.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df = dd.read_csv('flights.csv',dtype={'SCHEDULED_TIME': 'float64'})

# %%
df
# Out:
# Dask DataFrame Structure:
#                  YEAR  MONTH    DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME DEPARTURE_DELAY TAXI_OUT WHEELS_OFF SCHEDULED_TIME ELAPSED_TIME AIR_TIME DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME ARRIVAL_DELAY DIVERTED CANCELLED CANCELLATION_REASON AIR_SYSTEM_DELAY SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY WEATHER_DELAY
# npartitions=18
#                 int64  int64  int64       int64  object         int64      object         object              object               int64        float64         float64  float64    float64        float64      float64  float64    int64   float64  float64             int64      float64       float64    int64     int64              object          float64        float64       float64             float64       float64
# ...

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df.tail()
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 213554  2015     12   31            4      B6            688      N657JB
# 213555  2015     12   31            4      B6            745      N828JB
# 213556  2015     12   31            4      B6           1503      N913JB
# 213557  2015     12   31            4      B6            333      N527JB
# 213558  2015     12   31            4      B6            839      N534JB
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 213554            LAX                 BOS                 2359  ...
# 213555            JFK                 PSE                 2359  ...
# 213556            JFK                 SJU                 2359  ...
# 213557            MCO                 SJU                 2359  ...
# 213558            JFK                 BQN                 2359  ...
#
#         ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 31 entries, YEAR to WEATHER_DELAY
# dtypes: object(5), float64(15), int64(11)

# %%
df_pandas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
#df['SCHEDULED_TIME'] = df['SCHEDULED_TIME'].astype('int64')

# %%
df.isna().sum().compute()
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# ...

# %%
df.groupby('ORIGIN_AIRPORT').DEPARTURE_DELAY.mean().compute()
# Out:
# c:\program files\lib\multiprocessing\pool.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ORIGIN_AIRPORT
# ABE       8.844812
# ABI       5.783989
# ABQ       8.877015
# ABR      10.101056
# ABY       8.880046
#            ...
# 16218     0.615385
# 13502    -5.800000
# 13502    -5.000000
# 14025     8.000000
# 14222    -5.000000
# Name: DEPARTURE_DELAY, Length: 934, dtype: float64

# %%
df.DEPARTURE_DELAY.max().visualize()
# Out:
# Format: "png" not recognized. Use one of:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-24-359e8b6048b1> in <module>
# ----> 1 df.DEPARTURE_DELAY.max().visualize()
#
# c:\program files\lib\site-packages\dask\base.py in visualize(self, filename, format, optimize_graph, **kwargs)
#      96             format=format,
#      97             optimize_graph=optimize_graph,
# ---> 98             **kwargs
#      99         )
#     100
#
# c:\program files\lib\site-packages\dask\base.py in visualize(*args, **kwargs)
#     556         raise NotImplementedError("Unknown value color=%s" % color)
#     557
# --> 558     return dot_graph(dsk, filename=filename, **kwargs)
#     559
#     560
#
# c:\program files\lib\site-packages\dask\dot.py in dot_graph(dsk, filename, format, **kwargs)
#     270     """
#     271     g = to_graphviz(dsk, **kwargs)
# ...

# %%
df.AIR_SYSTEM_DELAY.sum().compute()
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# 14335762.0

# %%
df.info(memory_usage = 'deep')
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 31 entries, YEAR to WEATHER_DELAY
# dtypes: object(5), float64(16), int64(10)
# memory usage: 1.3 GB

# %%
import time
from tqdm import tqdm #nos ayuda a vizualizar procesos

# %%
for i in tqdm(range(2), desc = 'Primer_loop'):
    tqdm._instances.clear()
    for j in tqdm(range(5), desc = 'Segundo_loop'):
        time.sleep(5)
# Out:
# ...
# Primer_loop: 100%|███████████████████████████████████████████████████████████████████████| 2/2 [00:50<00:00, 25.05s/it]

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(0, int(1e8), (10000, 1000)))

# %%
tqdm.pandas()
# Out:
# C:\Users\GralG\AppData\Roaming\Python\Python37\site-packages\tqdm\std.py:670: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
df.groupby(0).progress_apply(lambda x: x**2)
# Out:
#  60%|██████████████████████████████████████████████▌                               | 5976/9999 [17:40<11:21,  5.90it/s]
